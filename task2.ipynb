# %%
import pandas as pd   
import numpy as np
import matplotlib.pyplot as plt
df1 = pd.read_csv('/home/jamuna/Downloads/Group_3_Python_Assignment-Main_Branch/Cause_Of_Death_Dataset/annual_number_of_deaths_by_cause.csv')
df1
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 8249     Zimbabwe  ZWE  2015                                          NaN
# 8250     Zimbabwe  ZWE  2016                                          NaN
# 8251     Zimbabwe  ZWE  2017                                          NaN
# 8252     Zimbabwe  ZWE  2018                                          NaN
# 8253     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# ...

# %%
#Setting Index , sets 'Year' as index
df1 = pd.read_csv('/home/jamuna/Downloads/Group_3_Python_Assignment-Main_Branch/Cause_Of_Death_Dataset/annual_number_of_deaths_by_cause.csv')
df1 = df1.set_index('Year')
df1
# Out:
#            Entity Code Number of executions (Amnesty International)  \
# Year
# 2007  Afghanistan  AFG                                           15
# 2008  Afghanistan  AFG                                           17
# 2009  Afghanistan  AFG                                            0
# 2011  Afghanistan  AFG                                            2
# 2012  Afghanistan  AFG                                           14
# ...           ...  ...                                          ...
# 2015     Zimbabwe  ZWE                                          NaN
# 2016     Zimbabwe  ZWE                                          NaN
# 2017     Zimbabwe  ZWE                                          NaN
# 2018     Zimbabwe  ZWE                                          NaN
# 2019     Zimbabwe  ZWE                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# Year
# 2007                                             2933.0
# ...

# %%
df1.plot(kind='line')
# Out:
# <Axes: >

# %%
df1.plot(kind='bar')
# Out:
# <Axes: >

# %%
'''df1.plot(kind='bar', figsize=(10, 6), width=0.8)  # Create a bar plot
plt.title('Annual Number of Deaths by Cause')  # Add a title
plt.xlabel('Year')  # Add a label to the x-axis
plt.ylabel('Number of Deaths')  # Add a label to the y-axis
plt.legend(title='Cause of Death', bbox_to_anchor=(1.05, 1), loc='upper left')  # Add a legend
plt.show() '''

# %%
# Renaming columns
df1 = df1.rename(columns={
    'Deaths - Meningitis - Sex: Both - Age: All Ages (Number)': 'Deaths_Meningitis',
    'Deaths - Neoplasms - Sex: Both - Age: All Ages (Number)': 'Deaths_Neoplasms',
    'Deaths - Fire, heat, and hot substances - Sex: Both - Age: All Ages (Number)': 'Deaths_Fire_heat_hot_substances',
    'Deaths - Malaria - Sex: Both - Age: All Ages (Number)': 'Deaths_Malaria',
    'Deaths - Drowning - Sex: Both - Age: All Ages (Number)': 'Deaths_Drowning',
    'Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)': 'Deaths_Interpersonal_violence',
    'Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Number)': 'Deaths_HIV_AIDS',
    'Deaths - Drug use disorders - Sex: Both - Age: All Ages (Number)': 'Deaths_Drug_use_disorders',
    'Deaths - Tuberculosis - Sex: Both - Age: All Ages (Number)': 'Deaths_Tuberculosis',
    'Deaths - Road injuries - Sex: Both - Age: All Ages (Number)': 'Deaths_Road_injuries',
    'Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)': 'Deaths_Maternal_disorders',
    'Deaths - Lower respiratory infections - Sex: Both - Age: All Ages (Number)': 'Deaths_Lower_respiratory_infections',
    'Deaths - Neonatal disorders - Sex: Both - Age: All Ages (Number)': 'Deaths_Neonatal_disorders',
    'Deaths - Alcohol use disorders - Sex: Both - Age: All Ages (Number)': 'Deaths_Alcohol_use_disorders',
    'Deaths - Exposure to forces of nature - Sex: Both - Age: All Ages (Number)': 'Deaths_Exposure_to_forces_of_nature',
    'Deaths - Diarrheal diseases - Sex: Both - Age: All Ages (Number)': 'Deaths_Diarrheal_diseases',
    'Deaths - Environmental heat and cold exposure - Sex: Both - Age: All Ages (Number)': 'Deaths_Environmental_heat_cold_exposure',
    'Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)': 'Deaths_Nutritional_deficiencies',
    'Deaths - Self-harm - Sex: Both - Age: All Ages (Number)': 'Deaths_Self_harm',
    'Deaths - Conflict and terrorism - Sex: Both - Age: All Ages (Number)': 'Deaths_Conflict_terrorism',
    'Deaths - Diabetes mellitus - Sex: Both - Age: All Ages (Number)': 'Deaths_Diabetes_mellitus',
    'Deaths - Poisonings - Sex: Both - Age: All Ages (Number)': 'Deaths_Poisonings',
    'Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Number)': 'Deaths_Protein_energy_malnutrition',
    'Terrorism (deaths)': 'Terrorism_deaths',
    'Deaths - Cardiovascular diseases - Sex: Both - Age: All Ages (Number)': 'Deaths_Cardiovascular_diseases',
    'Deaths - Chronic kidney disease - Sex: Both - Age: All Ages (Number)': 'Deaths_Chronic_kidney_disease',
    'Deaths - Chronic respiratory diseases - Sex: Both - Age: All Ages (Number)': 'Deaths_Chronic_respiratory_diseases',
    'Deaths - Cirrhosis and other chronic liver diseases - Sex: Both - Age: All Ages (Number)': 'Deaths_Cirrhosis_other_chronic_liver_diseases',
    'Deaths - Digestive diseases - Sex: Both - Age: All Ages (Number)': 'Deaths_Digestive_diseases',
    'Deaths - Acute hepatitis - Sex: Both - Age: All Ages (Number)': 'Deaths_Acute_hepatitis',
    "Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)": 'Deaths_Alzheimers_disease_other_dementias',
    "Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)": 'Deaths_Parkinsons_disease'
})
df1
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 8249     Zimbabwe  ZWE  2015                                          NaN
# 8250     Zimbabwe  ZWE  2016                                          NaN
# 8251     Zimbabwe  ZWE  2017                                          NaN
# 8252     Zimbabwe  ZWE  2018                                          NaN
# 8253     Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths_Meningitis  Deaths_Neoplasms  Deaths_Fire_heat_hot_substances  \
# ...

# %%
df1.plot(kind='bar', figsize=(10, 6), width=1.5)  # Create a bar plot
plt.title('Annual Number of Deaths by Cause')  # Add a title
plt.xlabel('Year')  # Add a label to the x-axis
plt.ylabel('Number of Deaths')  # Add a label to the y-axis
plt.legend(title='Cause of Death', bbox_to_anchor=(1.05, 1), loc='upper left')  # Add a legend
plt.show()

# %%
countries_to_plot = ['Africa', 'USA', 'China'] 
plt.figure(figsize=(10, 6))  # Set the figure size
df1['Deaths_Meningitis'].plot(kind='bar')  # Create a bar plot for 'Deaths_Meningitis'
plt.title('Number of Deaths due to Meningitis')  # Set the title
plt.xlabel('Year')  # Set the label for the x-axis
plt.ylabel('Number of Deaths')  # Set the label for the y-axi
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.tight_layout() 
plt.show()

# %%
df2 = pd.read_csv('/home/jamuna/Downloads/Group_3_Python_Assignment-Main_Branch/Cause_Of_Death_Dataset/Causes_Of_Death.csv')
df2
# Out:
#                                          Causes name  \
# 0                                         Meningitis
# 1                                          Neoplasms
# 2                     Fire, heat, and hot substances
# 3                                            Malaria
# 4                                           Drowning
# ...                                              ...
# 201757                            Digestive diseases
# 201758                               Acute hepatitis
# 201759       Alzheimer's disease and other dementias
# 201760                           Parkinson's disease
# 201761  Number of executions (Amnesty International)
#
#                                   Causes Full Description  Death Numbers  \
# 0       Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 1       Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2       Deaths - Fire, heat, and hot substances - Sex:...          481.0
# ...

# %%
df2 = pd.read_csv('/home/jamuna/Downloads/Group_3_Python_Assignment-Main_Branch/Cause_Of_Death_Dataset/Causes_Of_Death.csv')
df2 = df2.set_index('Year')
df2
# Out:
#                                        Causes name  \
# Year
# 2007                                    Meningitis
# 2007                                     Neoplasms
# 2007                Fire, heat, and hot substances
# 2007                                       Malaria
# 2007                                      Drowning
# ...                                            ...
# 2019                            Digestive diseases
# 2019                               Acute hepatitis
# 2019       Alzheimer's disease and other dementias
# 2019                           Parkinson's disease
# 2019  Number of executions (Amnesty International)
#
#                                 Causes Full Description  Death Numbers  \
# Year
# 2007  Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 2007  Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2007  Deaths - Fire, heat, and hot substances - Sex:...          481.0
# ...
